# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
pd.read_csv('CPW_QB_freq_cap_0403.csv')
# Out:
#    Unnamed: 0  pad_size(mm)  coupling_len(um)  coupling_gap(um)  buffer(um)  \
# 0           0         0.250              45.0              15.0       188.0
# 1           1         0.235              40.0              15.0       184.0
# 2           2         0.208              22.0              15.0       193.0
# 3           3         0.245              45.0              15.0       250.0
# 4           4         0.223              30.0              15.0       210.0
# 5           5         0.214              30.0              15.0       210.0
# 6           6         0.235              25.0              15.0       210.0
# 7           7         0.225              22.0              15.0       210.0
# 8           8         0.206              30.0              20.0       210.0
# 9           9         0.193              30.0              20.0       252.0
#
#    offset  target_freq(GHz)  target_res_freq(GHz)   Cj (fF)  Lj (nH)  ...  \
# ...

# %%
pd.read_csv('educated_guess_0403.csv')
# Out:
#    Unnamed: 0  Target_qb_Freq(GHz)  Sizes (um)   Ljs  Ljs (nH)  Buffers (um)  \
# 0           0                  4.0         250  13nH        13           188
# 1           1                  4.2         235  13nH        13           184
# 2           2                  4.4         208  13nH        13           193
# 3           3                  4.6         245  10nH        10           250
# 4           4                  4.8         223  10nH        10           210
# 5           5                  5.0         214  10nH        10           210
# 6           6                  5.2         235   8nH         8           210
# 7           7                  5.4         225   8nH         8           210
# 8           8                  5.6         206   8nH         8           210
# 9           9                  5.8         193   8nH         8           252
#
#    Offsets (mm)       TQx     TQy  Small  TQ_mir  CPW_freq_predict(GHz)  \
# ...
