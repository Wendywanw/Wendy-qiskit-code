# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import astropy.units as u
import astropy.constants as c

# %%
data = pd.read_csv(r'/Users/wendy/Desktop/Wendy-qiskit-code/data/Buggy_freqs/2023_03_04/Two_QB_distance.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_csv(r'/Users/wendy/Desktop/Wendy-qiskit-code/data/Buggy_freqs/2023_03_04/Two_QB_distance.csv')
#
# NameError: name 'pd' is not defined

# %%
data
# Out:
#    Unnamed: 0  Pos1_x(mm)  Pos2_x(mm)  C_Q1_Q2(fF)  C_Q1_g(fF)  C_Q2_g(fF)  \
# 0           0           0   14.500000      -0.4923  -107.03128   -97.18904
# 1           1           0   12.961111      -0.4923  -107.03128   -97.18904
# 2           2           0   11.422222      -0.4923  -107.03128   -97.18904
# 3           3           0    9.883333      -0.4923  -107.03128   -97.18904
# 4           4           0    8.344444      -0.4923  -107.03128   -97.18904
# 5           5           0    6.805556      -0.4923  -107.03128   -97.18904
# 6           6           0    5.266667      -0.4923  -107.03128   -97.18904
# 7           7           0    3.727778      -0.4923  -107.03128   -97.18904
# 8           8           0    2.188889      -0.4923  -107.03128   -97.18904
# 9           9           0    0.650000      -0.4923  -107.03128   -97.18904
#
#    Freq_Q1(GHz)  Freq_Q2(GHz)  Freq_C1(GHz)  Freq_C2(GHz)  Freq_Q1_EPR(MHz)  \
# ...

# %%
sns.relplot(
    data=data, kind="scatter",
    y="Freq_C1_EPR(MHz)", hue="chi_q2_c1(MHz)", x = 'Pos2_x(mm)')#, size="Pos2_x(mm)")# col="chi_q12(MHz)",)
    #hue="choice", size="coherence", style="choice",
#     facet_kws=dict(sharex=False),
# )
